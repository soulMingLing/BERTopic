# %%
import jieba
# Out:
# C:\Anaconda\envs\py39\lib\site-packages\jieba\_compat.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
with open('师德师风-3.txt', 'r', encoding='utf-8') as file:
    docs = file.read().split('\n')
    print('文本内容： ', len(docs), docs[0])
# Out:
# 文本内容：  859 二零二一年。

# %%
jieba.load_userdict("userdict.txt") #用户字典，这些词不需要切分
stopwords = [line.strip() for line in open(
    'stopwords.txt', encoding='UTF-8').readlines()]
print('停用词：', stopwords[:5])
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\hp\AppData\Local\Temp\jieba.cache
# Loading model cost 0.398 seconds.
# Prefix dict has been built successfully.
# 停用词： ['中央', 'OO', '四月', '河南', '专程来']

# %%
cutted_text = []
for i, line_text in enumerate(docs):
    if len(line_text) > 512:
      line_text = line_text[:512] # 这里可以只保留前512个字符，以保证参与切词的文本，和参与生成词向量的文本，都是512个字符
      print('文本过长，仅保留前512个字符：', i, line_text)
    seg_list = jieba.cut(line_text)
    # 过滤
    filtered_words = []
    for word in seg_list:
       if (word not in stopwords and (len(word)) >= 2 and not word.isdigit()): # 去除停用词 and 单词长度>=2 and 不能是纯数字
           # if word=='要管':
           #     print(1)
           filtered_words.append(word)
    # print(i, filtered_words)
    if len(filtered_words) > 0:
        cutted_text.append(' '.join(filtered_words))

print('切词后： ', len(cutted_text), cutted_text[0])
# Out:
# 切词后：  848 二零二一年

# %%
with open('师德师风切词.txt', 'w', encoding='utf-8') as f:
    f.write('\n'.join(cutted_text))
